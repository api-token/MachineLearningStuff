274, 0.4, 1], [0.5882352941176471, 0.09803921568627451, 0.9176470588235294, 1], [0.5294117647058824, 0.792156862745098, 0.7450980392156863, 1], [0.6352941176470588, 0.3411764705882353, 0.9019607843137255, 1], [0.9137254901960784, 0.43529411764705883, 0.09803921568627451, 1], [0, 0.396078431372549, 0.5843137254901961, 0], [0.01568627450980392, 0.5294117647058824, 0.4980392156862745, 1], [0.09803921568627451, 0.9803921568627451, 0.23921568627450981, 0], [0.403921568627451, 0.5725490196078431, 0.38823529411764707, 0], [0.7294117647058823, 0.16862745098039217, 0.796078431372549, 1], [0.788235294117647, 0.22745098039215686, 0.027450980392156862, 1], [0.8117647058823529, 0.47058823529411764, 0.9215686274509803, 0], [0.1568627450980392, 0.4980392156862745, 0.13333333333333333, 1], [0.00392156862745098, 0.5882352941176471, 0.0196078431372549, 1], [0.06274509803921569, 0.054901960784313725, 0.8549019607843137, 1], [0.3411764705882353, 0.9019607843137255, 0.2, 0], [0.9568627450980393, 0.9333333333333333, 0.48627450980392156, 1], [0.6392156862745098, 0.6235294117647059, 0.7490196078431373, 1], [0.792156862745098, 0.5254901960784314, 0.25882352941176473, 0], [0.7764705882352941, 0.47843137254901963, 0.4117647058823529, 0], [0.8470588235294118, 0.30980392156862746, 0.4588235294117647, 1], [0.0784313725490196, 0.13333333333333333, 0.25882352941176473, 1], [0.45098039215686275, 0.21568627450980393, 0.00784313725490196, 1]]
    , np.int32)

unknown = [208, 164, 153]

def sigmoid(x):
    return 1/(1 + np.exp(-x))

def train():
    w1 = np.random.randn()*.2-.1
    w2 = np.random.randn()*.2-.1
    w3 = np.random.randn()*.2-.1
    b = np.random.randn()*.2-.1
    learning_rate = 0.01

    for iter in range(900000):
        random_index = np.floor(np.random.rand() * (data.shape[0]-1))
        point = data[int(random_index)];
        target = point[3]

        z = w1 * point[0] + w2 * point[1] + w3 * point[2] + b
        prediction = sigmoid(z)

        cost = (prediction - target) ** 2

        dcost_dpred = 2 * (prediction - target)

        dpred_dz = sigmoid(z) * (1-sigmoid(z))

        dz_dw1 = point[0]
        dz_dw2 = point[1]
        dz_dw3 = point[2]
        dz_db = 1

        dcost_dw1 = dcost_dpred * dpred_dz * dz_dw1
        dcost_dw2 = dcost_dpred * dpred_dz * dz_dw2
        dcost_dw3 = dcost_dpred * dpred_dz * dz_dw3
        dcost_db = dcost_dpred * dpred_dz * dz_db

        w1 -= learning_rate * dcost_dw1
        w2 -= learning_rate * dcost_dw2
        w3 -= learning_rate * dcost_dw3
        b -= learning_rate * dcost_db

    return [w1, w2, w3, b]

vals = train()
print(str(vals))
# Out:
# [-0.34017167361478273, -0.01362591782520721, -0.5328038568339214, 1.1326186404511025]

# %%
def testTrained(trainData, testEntry):
    z = trainData[0] * testEntry[0] + trainData[1] * testEntry[1] + trainData[2] * testEntry[2] + trainData[3]
    return sigmoid(z)

testTrained(vals, unknown)
# Out:
# 2.4509388132826697e-67
